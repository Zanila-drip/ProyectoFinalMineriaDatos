# %% [markdown]
# ## Conexión y utilidades

# %%
from pymongo import MongoClient
import gridfs
from bson import ObjectId

client = MongoClient("mongodb://localhost:27017/")
db = client['trafico']
fs = gridfs.GridFS(db)
videos_col = db['Videos']
frames_col = db['VideosFrames']
videos_reconstruidos_col = db['VideosReconstruidos']

# %% [markdown]
# ## Listar todos los videos y sus IDs

# %%
for video in videos_col.find():
    print("video_id:", video["_id"], "| nombre:", video["nombre"], "| fecha:", video["fecha_subida"])
# Out:
# video_id: 6847bb810270edd78fabb649 | nombre: tradffic7.mp4 | fecha: 2025-06-09 22:58:41.913000

# %% [markdown]
# ##  Consulta frames de un video específico

# %%
video_id = ObjectId("6847bb810270edd78fabb649")
for frame in frames_col.find({"video_id": video_id}).sort("frame_num", 1):
    print("frame_num:", frame["frame_num"], "| gridfs_id:", frame.get("gridfs_id"), "| metricas:", frame.get("metricas"))
# Out:
# frame_num: 0 | gridfs_id: 6847bb820270edd78fabb64a | metricas: {'total_vehicles': 2, 'by_class': {'car': 2}, 'average_confidence': 0.8837334215641022, 'timestamp': datetime.datetime(2025, 6, 9, 22, 58, 42, 464000), 'frame_num': 0, 'video_id': ObjectId('6847bb810270edd78fabb649'), 'waiting_time': 4, 'traffic_density': 0.2, 'hour': 22, 'day_of_week': 0, 'weather': 'cloudy'}
# frame_num: 1 | gridfs_id: 6847bb820270edd78fabb64e | metricas: {'total_vehicles': 2, 'by_class': {'car': 2}, 'average_confidence': 0.9280883371829987, 'timestamp': datetime.datetime(2025, 6, 9, 22, 58, 42, 810000), 'frame_num': 1, 'video_id': ObjectId('6847bb810270edd78fabb649'), 'waiting_time': 4, 'traffic_density': 0.2, 'hour': 22, 'day_of_week': 0, 'weather': 'sunny'}
# frame_num: 2 | gridfs_id: 6847bb830270edd78fabb652 | metricas: {'total_vehicles': 3, 'by_class': {'car': 3}, 'average_confidence': 0.904593308766683, 'timestamp': datetime.datetime(2025, 6, 9, 22, 58, 43, 123000), 'frame_num': 2, 'video_id': ObjectId('6847bb810270edd78fabb649'), 'waiting_time': 6, 'traffic_density': 0.3, 'hour': 22, 'day_of_week': 0, 'weather': 'cloudy'}
# frame_num: 3 | gridfs_id: 6847bb830270edd78fabb656 | metricas: {'total_vehicles': 4, 'by_class': {'car': 4}, 'average_confidence': 0.8957779556512833, 'timestamp': datetime.datetime(2025, 6, 9, 22, 58, 43, 448000), 'frame_num': 3, 'video_id': ObjectId('6847bb810270edd78fabb649'), 'waiting_time': 8, 'traffic_density': 0.4, 'hour': 22, 'day_of_week': 0, 'weather': 'sunny'}
# frame_num: 4 | gridfs_id: 6847bb830270edd78fabb65a | metricas: {'total_vehicles': 3, 'by_class': {'car': 3}, 'average_confidence': 0.9055291612943014, 'timestamp': datetime.datetime(2025, 6, 9, 22, 58, 43, 772000), 'frame_num': 4, 'video_id': ObjectId('6847bb810270edd78fabb649'), 'waiting_time': 6, 'traffic_density': 0.3, 'hour': 22, 'day_of_week': 0, 'weather': 'sunny'}
# frame_num: 5 | gridfs_id: 6847bb840270edd78fabb65e | metricas: {'total_vehicles': 4, 'by_class': {'car': 4}, 'average_confidence': 0.7832132428884506, 'timestamp': datetime.datetime(2025, 6, 9, 22, 58, 44, 106000), 'frame_num': 5, 'video_id': ObjectId('6847bb810270edd78fabb649'), 'waiting_time': 8, 'traffic_density': 0.4, 'hour': 22, 'day_of_week': 0, 'weather': 'sunny'}
# frame_num: 6 | gridfs_id: 6847bb840270edd78fabb662 | metricas: {'total_vehicles': 3, 'by_class': {'car': 3}, 'average_confidence': 0.8961549401283264, 'timestamp': datetime.datetime(2025, 6, 9, 22, 58, 44, 419000), 'frame_num': 6, 'video_id': ObjectId('6847bb810270edd78fabb649'), 'waiting_time': 6, 'traffic_density': 0.3, 'hour': 22, 'day_of_week': 0, 'weather': 'sunny'}
# frame_num: 7 | gridfs_id: 6847bb840270edd78fabb666 | metricas: {'total_vehicles': 2, 'by_class': {'car': 2}, 'average_confidence': 0.9307513236999512, 'timestamp': datetime.datetime(2025, 6, 9, 22, 58, 44, 730000), 'frame_num': 7, 'video_id': ObjectId('6847bb810270edd78fabb649'), 'waiting_time': 4, 'traffic_density': 0.2, 'hour': 22, 'day_of_week': 0, 'weather': 'cloudy'}
# frame_num: 8 | gridfs_id: 6847bb850270edd78fabb66a | metricas: {'total_vehicles': 2, 'by_class': {'car': 2}, 'average_confidence': 0.9226598739624023, 'timestamp': datetime.datetime(2025, 6, 9, 22, 58, 45, 59000), 'frame_num': 8, 'video_id': ObjectId('6847bb810270edd78fabb649'), 'waiting_time': 4, 'traffic_density': 0.2, 'hour': 22, 'day_of_week': 0, 'weather': 'cloudy'}
# frame_num: 9 | gridfs_id: 6847bb850270edd78fabb66e | metricas: {'total_vehicles': 2, 'by_class': {'car': 2}, 'average_confidence': 0.9227437078952789, 'timestamp': datetime.datetime(2025, 6, 9, 22, 58, 45, 374000), 'frame_num': 9, 'video_id': ObjectId('6847bb810270edd78fabb649'), 'waiting_time': 4, 'traffic_density': 0.2, 'hour': 22, 'day_of_week': 0, 'weather': 'sunny'}
# frame_num: 10 | gridfs_id: 6847bb850270edd78fabb672 | metricas: {'total_vehicles': 2, 'by_class': {'car': 2}, 'average_confidence': 0.9242312014102936, 'timestamp': datetime.datetime(2025, 6, 9, 22, 58, 45, 660000), 'frame_num': 10, 'video_id': ObjectId('6847bb810270edd78fabb649'), 'waiting_time': 4, 'traffic_density': 0.2, 'hour': 22, 'day_of_week': 0, 'weather': 'rainy'}

# %% [markdown]
# ## Limpiar datos de prueba o antiguos

# %%
# Eliminar todos los videos y frames marcados como test
videos_col.delete_many({"es_test": True})
frames_col.delete_many({"es_test": True})

# Eliminar todos los archivos de GridFS marcados como test (si guardaste ese campo)
for frame in frames_col.find({"es_test": True}):
    if "gridfs_id" in frame:
        fs.delete(frame["gridfs_id"])
print("Datos de prueba eliminados.")
# Out:
# Datos de prueba eliminados.

# %% [markdown]
# ## Eliminar todos los archivos de GridFS (¡CUIDADO!

# %%
for file in fs.find():
    fs.delete(file._id)
print("Todos los archivos de GridFS eliminados.")
# Out:
# Todos los archivos de GridFS eliminados.

# %% [markdown]
# ## Consultar frames con más de X autos detectados

# %%
for frame in frames_col.find({"metricas.by_class.car": {"$gt": 10}}):
    print("frame_num:", frame["frame_num"], "| autos:", frame["metricas"]["by_class"]["car"])

# %% [markdown]
# ## Descargar y visualizar una imagen desde GridFS

# %%
import cv2
import numpy as np
from IPython.display import Image, display

frame = frames_col.find_one({"video_id": video_id, "frame_num": 0})  # Cambia el frame_num si quieres otro
if frame and "gridfs_id" in frame:
    img_bytes = fs.get(frame["gridfs_id"]).read()
    nparr = np.frombuffer(img_bytes, np.uint8)
    img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
    cv2.imwrite("frame_temp.jpg", img)
    display(Image(filename="frame_temp.jpg"))
else:
    print("No se encontró el frame o gridfs_id.")
# Out:
# No se encontró el frame o gridfs_id.

# %% [markdown]
# ## Estadísticas rápidas

# %%
print("Total de videos:", videos_col.count_documents({}))
print("Total de frames:", frames_col.count_documents({}))
print("Total de videos reconstruidos:", videos_reconstruidos_col.count_documents({}))
# Out:
# Total de videos: 1
# Total de frames: 11
# Total de videos reconstruidos: 1

# %% [markdown]
# ## Eliminar TODOS los videos, frames y videos reconstruidos

# %%
videos_col.delete_many({})
frames_col.delete_many({})
videos_reconstruidos_col.delete_many({})

for file in fs.find():
    fs.delete(file._id)

print("Todos los datos y archivos de GridFS han sido eliminados!!!")
# Out:
# Todos los datos y archivos de GridFS han sido eliminados!!!
